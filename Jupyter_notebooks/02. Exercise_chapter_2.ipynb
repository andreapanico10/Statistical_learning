# %% [markdown]
# # College dataset

# %% [markdown]
# This exercise relates to the College data set, which can be found in the file College.csv on the book website. It contains a number of variables for 777 different universities and colleges in the US.

# %% [markdown]
# • Private : Public/private indicator<br>
# • Apps : Number of applications received<br>
# • Accept : Number of applicants accepted<br>
# • Enroll : Number of new students enrolled<br>
# • Top10perc : New students from top 10 % of high school class • Top25perc : New students from top 25 % of high school class • F.Undergrad : Number of full-time undergraduates<br>
# • P.Undergrad : Number of part-time undergraduates<br>
# • Outstate : Out-of-state tuition<br>
# • Room.Board : Room and board costs<br>
# • Books : Estimated book costs<br>
# • Personal : Estimated personal spending<br>
# • PhD : Percent of faculty with Ph.D.s<br>
# • Terminal : Percent of faculty with terminal degree<br>
# • S.F.Ratio : Student/faculty ratio<br>
# • perc.alumni : Percent of alumni who donate<br>
# • Expend : Instructional expenditure per student<br>
# • Grad.Rate : Graduation rate<br>

# %% [markdown]
# (a) Use the pd.read_csv() function to read the data into Python. Call the loaded data college. Make sure that you have the directory set to the correct location for the data.<br><br>
# (b) Look at the data used in the notebook by creating and running a new cell with just the code college in it. You should notice that the first column is just the name of each university in a column named something like Unnamed: 0. We don’t really want pandas to treat this as data. However, it may be handy to have these names for later.

# %%
import pandas as pd
from matplotlib import pyplot as plt

college_df = pd.read_csv('..//Datasets//College.csv', index_col=0)

# Set display options to show all rows and columns without truncation
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)  # To prevent wrapping of long lines
college_df = college_df.rename_axis("College", axis="index")
college_df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# (c) Use the describe() method of to produce a numerical summary of the variables in the data set.

# %%
college_df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# (d) Use the pd.plotting.scatter_matrix() function to produce a scatterplotmatrixofthefirstcolumns[Top10perc, Apps, Enroll]. Recall that you can reference a list C of columns of a data frame
# A using A[C].

# %%
pd.plotting.scatter_matrix(college_df[['Top10perc', 'Apps', 'Enroll']])
plt.show()

# %% [markdown]
# (e) Use the boxplot() method of college to produce side-by-side boxplots of Outstate versus Private.

# %%
college_df.boxplot(column='Outstate', by='Private')
plt.show()

# %% [markdown]
# (f) Create a new qualitative variable, called Elite, by binning the Top10perc variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.<br><br>
# Use the value_counts() method of college['Elite'] to see how many elite universities there are. Finally, use the boxplot() method again to produce side-by-side boxplots of Outstate versus Elite.

# %%
college_df['Elite'] = pd.cut(college_df['Top10perc'], [0,50,100],labels=['No', 'Yes'])

# Rispetto al libro ho 'corretto' perchè lì magari i dati erano espressi in percentuale
# ed il comando suggerito era:
#college_df['Elite'] = pd.cut(college_df['Top10perc'], [0,0.5,1],labels=['No', 'Yes'])

# %%
college_df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college_df['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college_df.boxplot(column='Outstate', by='Elite')
plt.show()

# %% [markdown]
# (g) Use the plot.hist() method of college to produce some histograms with differing numbers of bins for a few of the quantitative variables. The command plt.subplots(2, 2) may be use- ful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.

# %%
# Create a 2x3 subplot grid
fig, axes = plt.subplots(2, 3, figsize=(10, 8))
axes[0, 0].hist(college_df['Outstate'], bins=6, color='blue')
axes[0, 0].set_title('Outstate')
axes[0, 1].hist(college_df['PhD'], bins=6, color='lightblue')
axes[0, 1].set_title('PhD')
axes[0, 2].hist(college_df['Top10perc'], bins=6, color='lightblue')
axes[0, 2].set_title('Top10perc')

axes[1, 0].hist(college_df['Apps'], bins=10, color='lightblue')
axes[1, 0].set_title('Apps')
axes[1, 1].hist(college_df['Accept'], bins=10, color='lightblue')
axes[1, 1].set_title('Accept')
axes[1, 2].hist(college_df['Enroll'], bins=10, color='lightblue')
axes[1, 2].set_title('Enroll')

plt.show()

# %% [markdown]
# (h) Continue exploring the data, and provide a brief summary of what you discover.

# %%
tot_apps = college_df['Apps'].sum()
tot_accepted = college_df['Accept'].sum()
tot_enroll = college_df['Enroll'].sum()

# %%
plt.hist(range(3), bins=3, weights=[tot_apps, tot_accepted, tot_enroll], rwidth=0.3)

# Customize the appearance
plt.title('Apps vs Accept vs Enroll')
plt.xlabel('Bins')
plt.ylabel('#')
plt.xticks(range(3), ['Apps', 'Accept', 'Enroll'])

plt.show()

# %% [markdown]
# 9. This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.<br><br>
# (a) Which of the predictors are quantitative, and which are qualitative?

# %%
auto_df = pd.read_csv('..//Datasets//Auto.csv', index_col=-1)
auto_df.head()
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1

# %%
# Get the data types of each column
column_data_types = auto_df.dtypes
column_data_types
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# dtype: object

# %% [markdown]
# (b) What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy.

# %%
auto_df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
import numpy as np

min_mpg = np.min(auto_df['mpg'])
max_mpg = np.max(auto_df['mpg'])

min_mpg, max_mpg
# Out:
# (9.0, 46.6)

# %% [markdown]
# (c) What is the mean and standard deviation of each quantitative predictor?

# %%
mean_mpg = round(np.mean(auto_df['mpg']),3)
std_mpg = round(np.std(auto_df['mpg']),3)

mean_mpg, std_mpg
# Out:
# (23.516, 7.816)

# %% [markdown]
# (d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
subset_auto_df = auto_df.drop(auto_df.index[9:85])
subset_auto_df.head()
# Out:
#                      mpg  cylinders  displacement horsepower  weight  \
# name
# buick skylark 320   15.0          8         350.0        165    3693
# plymouth satellite  18.0          8         318.0        150    3436
# amc rebel sst       16.0          8         304.0        150    3433
# ford torino         17.0          8         302.0        140    3449
# buick century 350   13.0          8         350.0        175    4100
#
#                     acceleration  year  origin
# name
# buick skylark 320           11.5    70       1
# plymouth satellite          11.0    70       1
# amc rebel sst               12.0    70       1
# ford torino                 10.5    70       1
# buick century 350           13.0    73       1

# %%
subset_auto_df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  280.000000  280.000000    280.000000   280.000000    280.000000
# mean    25.129286    5.285714    179.942857  2885.407143     15.724643
# std      8.015303    1.640813     96.356289   798.940404      2.572044
# min     11.000000    3.000000     68.000000  1755.000000      9.500000
# 25%     18.175000    4.000000     98.000000  2169.250000     14.000000
# 50%     24.750000    4.000000    140.000000  2720.000000     15.500000
# 75%     31.500000    6.000000    250.000000  3438.250000     17.300000
# max     46.600000    8.000000    455.000000  4952.000000     24.600000
#
#              year      origin
# count  280.000000  280.000000
# mean    77.575000    1.642857
# std      2.992479    0.830178
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     78.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# (e) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.

# %%
pd.plotting.scatter_matrix(auto_df[['mpg', 'weight', 'acceleration']])
plt.show()

# %%
auto_df['year'].value_counts()
# Out:
# year
# 73    40
# 78    36
# 76    34
# 75    30
# 82    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: count, dtype: int64

# %%
auto_df.boxplot(column='acceleration', by='year')
plt.show()

# %%
auto_df.boxplot(column='acceleration', by='origin')
plt.show()

# %%
auto_df.boxplot(column='weight', by='origin')
plt.show()

# %% [markdown]
# (f) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.

# %%
pd.plotting.scatter_matrix(auto_df)
plt.show()

# %% [markdown]
# 10. This exercise involves the Boston housing data set.<br><br>
# (a) To begin, load in the Boston data set, which is part of the ISLP
# library.

# %%
# Load the Boston dataset
boston_df = pd.read_csv('..//Datasets//HousingData.csv')
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %% [markdown]
# (b) How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
boston_df.shape
# Out:
# (506, 13)

# %% [markdown]
# The medv variable is the target variable.
#
# ## Data description
#
# The Boston data frame has 506 rows and 14 columns.
#
# This data frame contains the following columns:
#
# ## crim
# per capita crime rate by town.
#
# ## zn
# proportion of residential land zoned for lots over 25,000 sq.ft.
#
# ## indus
# proportion of non-retail business acres per town.
#
# ## chas
# Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# ## nox
# nitrogen oxides concentration (parts per 10 million).
#
# ## rm
# average number of rooms per dwelling.
#
# ## age
# proportion of owner-occupied units built prior to 1940.
#
# ## dis
# weighted mean of distances to five Boston employment centres.
#
# ## rad
# index of accessibility to radial highways.
#
# ## tax
# full-value property-tax rate per $10,000.
#
# ## ptratio
# pupil-teacher ratio by town.
#
# ## black
# 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#
# ## lstat
# lower status of the population (percent).
#
# ## medv
# median value of owner-occupied homes in $1000s.

# %% [markdown]
# (c) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %%
pd.plotting.scatter_matrix(boston_df[['LSTAT','MEDV']])
plt.show()

# %%
pd.plotting.scatter_matrix(boston_df[['DIS','CRIM']])
plt.show()

# %%
pd.plotting.scatter_matrix(boston_df[['RM','MEDV']])
plt.show()

# %% [markdown]
# (d) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %%
# Create the correlation matrix
correlation_matrix = boston_df.corr()

# Print or display the correlation matrix
correlation_matrix[['CRIM']][abs(correlation_matrix['CRIM']) > 0.45]
# Out:
#           CRIM
# CRIM  1.000000
# RAD   0.624765
# TAX   0.580595

# %% [markdown]
# ## crim
# per capita crime rate by town.
#
# ## rad
# index of accessibility to radial highways.
#
# ## tax
# full-value property-tax rate per $10,000.

# %% [markdown]
# (e) Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
boston_df[['CRIM','TAX','PTRATIO']].describe()
# Out:
#              CRIM         TAX     PTRATIO
# count  486.000000  506.000000  506.000000
# mean     3.611874  408.237154   18.455534
# std      8.720192  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.081900  279.000000   17.400000
# 50%      0.253715  330.000000   19.050000
# 75%      3.560263  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %%
boston_df[boston_df['CRIM'] > 10].sort_values(by='CRIM', ascending=False).head()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 380  88.9762  0.0   18.1   0.0  0.671  6.968   91.9  1.4165   24  666
# 418  73.5341  0.0   18.1   0.0  0.679  5.957  100.0  1.8026   24  666
# 405  67.9208  0.0   18.1   0.0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1   0.0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1   0.0  0.693  4.519  100.0  1.6582   24  666
#
#      PTRATIO       B  LSTAT  MEDV
# 380     20.2  396.90  17.21  10.4
# 418     20.2   16.45  20.62   8.8
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# 414     20.2   88.27  36.98   7.0

# %%
boston_df[boston_df['TAX'] > 660].sort_values(by='TAX', ascending=False).head()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 492  0.11132  0.0  27.74   0.0  0.609  5.983  83.5  2.1099    4  711     20.1
# 491  0.10574  0.0  27.74   0.0  0.609  5.983  98.8  1.8681    4  711     20.1
# 490  0.20746  0.0  27.74   0.0  0.609  5.093  98.0  1.8226    4  711     20.1
# 489  0.18337  0.0  27.74   0.0  0.609  5.414  98.3  1.7554    4  711     20.1
# 488  0.15086  0.0  27.74   0.0  0.609  5.454  92.7  1.8209    4  711     20.1
#
#           B  LSTAT  MEDV
# 492  396.90  13.35  20.1
# 491  390.11  18.07  13.6
# 490  318.43  29.68   8.1
# 489  344.05  23.97   7.0
# 488  395.09  18.06  15.2

# %%
boston_df[boston_df['PTRATIO'] > 20].sort_values(by='PTRATIO', ascending=False).head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE      DIS  RAD  TAX  \
# 355  0.10659   NaN   1.91   0.0  0.413  5.936   NaN  10.5857    4  334
# 354  0.04301  80.0   1.91   0.0  0.413  5.663  21.9  10.5857    4  334
# 138  0.24980   0.0  21.89   0.0  0.624  5.857   NaN   1.6686    4  437
# 137  0.35233   0.0  21.89   0.0  0.624  6.454  98.4   1.8498    4  437
# 129  0.88125   0.0  21.89   0.0  0.624  5.637  94.7   1.9799    4  437
#
#      PTRATIO       B  LSTAT  MEDV
# 355     22.0  376.04   5.57  20.6
# 354     22.0  382.80   8.05  18.2
# 138     21.2  392.04  21.32  13.3
# 137     21.2  394.08  14.59  17.1
# 129     21.2  396.90  18.34  14.3

# %%
boston_df[(boston_df['CRIM'] > 30) &  (boston_df['TAX'] > 660) & (boston_df['PTRATIO'] > 20)]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 380  88.9762  0.0   18.1   0.0  0.671  6.968   91.9  1.4165   24  666
# 398  38.3518  0.0   18.1   0.0  0.693  5.453  100.0  1.4896   24  666
# 404  41.5292  0.0   18.1   0.0  0.693  5.531   85.4  1.6074   24  666
# 405  67.9208  0.0   18.1   0.0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1   0.0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1   0.0  0.693  4.519  100.0  1.6582   24  666
# 418  73.5341  0.0   18.1   0.0  0.679  5.957  100.0  1.8026   24  666
# 427  37.6619  NaN   18.1   0.0  0.679  6.202   78.7  1.8629   24  666
#
#      PTRATIO       B  LSTAT  MEDV
# 380     20.2  396.90  17.21  10.4
# 398     20.2  396.90  30.59   5.0
# 404     20.2  329.46  27.38   8.5
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# 414     20.2   88.27  36.98   7.0
# 418     20.2   16.45  20.62   8.8
# 427     20.2   18.82  14.52  10.9

# %%
plt.figure(figsize=(10, 8))

plt.subplot(131)
plt.boxplot(boston_df['CRIM'])

plt.subplot(132)
plt.boxplot(boston_df['TAX'])

plt.subplot(133)
plt.boxplot(boston_df['PTRATIO'])

# Adjust spacing between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# (f) How many of the suburbs in this data set bound the Charles river?

# %%
boston_df['CHAS'].value_counts()
# Out:
# CHAS
# 0.0    452
# 1.0     34
# Name: count, dtype: int64

# %% [markdown]
# (g) What is the median pupil-teacher ratio among the towns in this data set?

# %%
np.median(boston_df['PTRATIO'])
# Out:
# 19.05

# %% [markdown]
# (h) Which suburb of Boston has lowest median value of owner- occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
boston_df['AGE']
# Out:
# 0       65.2
# 1       78.9
# 2       61.1
# 3       45.8
# 4       54.2
# 5       58.7
# 6       66.6
# 7       96.1
# 8      100.0
# 9       85.9
# 10      94.3
# 11      82.9
# 12      39.0
# 13      61.8
# 14      84.5
# 15      56.5
# 16      29.3
# 17      81.7
# 18      36.6
# 19      69.5
# 20      98.1
# 21      89.2
# 22      91.7
# 23     100.0
# 24      94.1
# 25      85.7
# 26      90.3
# 27      88.8
# 28      94.4
# 29      87.3
# 30      94.1
# 31     100.0
# 32      82.0
# 33      95.0
# 34      96.9
# 35      68.2
# 36      61.4
# 37      41.5
# 38      30.2
# 39      21.8
# 40      15.8
# 41       2.9
# 42       6.6
# 43       6.5
# 44      40.0
# 45      33.8
# 46      33.3
# 47      85.5
# 48      95.3
# 49      62.0
# 50      45.7
# 51      63.0
# 52      21.1
# 53      21.4
# 54      47.6
# 55      21.9
# 56      35.7
# 57      40.5
# 58      29.2
# 59      47.2
# 60      66.2
# 61      93.4
# 62      67.8
# 63      43.4
# 64      59.5
# 65      17.8
# ...

# %% [markdown]
# (i) In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.

# %%
boston_df[boston_df['RM'] > 7].shape[0], boston_df[boston_df['RM'] > 8].shape[0]
# Out:
# (64, 13)
